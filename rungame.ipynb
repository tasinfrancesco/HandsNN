# %% [markdown]
# <a href="https://colab.research.google.com/github/tasinfrancesco/HandsNN/blob/main/rungame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import abc

class Player(abc.ABC):
  def __init__(self, handnum):
    self.hands = [handnum-1, handnum-1]
    self.handmax = handnum

  def changehands(self, val, hand):
    newhands = (self.hands[hand]+val)% self.handmax
    self.hands = sorted(newhands)

  def currstate(self):
    return self.hands

  @abc.abstractclassmethod
  def nextmove(self, opponent: list)->list:
    pass


class HumanPlayer(Player):

  def nextmove(self, opponent):
    print("Next Move:")
    if self.hands[1]!=0:
      own = -1
      while own not in [0, 1]:
        own = int(input("Your Hand (0 or 1)"))

    else:
      own = 0
    if opponent[1]!=0:
      opp = -1
      while opp not in [0, 1]:
        opp = int(input("Their Hand (0 or 1)"))
    else:
      opp = 0
    return own, opp

class NNPlayer(Player):
  def nextmove(move):
    return move

def handsgame(handnum, player_1 = "h", player_2 = "h", *print=False):
  #initialise players
  if player_1 == "h":
    p1 = HumanPlayer(handnum)
  else:
    p1 = NNPlayer(handnum)
  if player_2 == "h":
    p2=HumanPlayer(handnum)
  else:
    p2=NNPlayer(handnum)




  #Print initial
  if player_1 != "h" and player_2 != "h":

# %%
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of google.colab._kernel.Kernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.
